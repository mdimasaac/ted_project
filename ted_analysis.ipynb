# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
pip install matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python 3.10\lib\site-packages)
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the 'd:\Python 3.10\python.exe -m pip install --upgrade pip' command.
# ...

# %%
df = pd.read_csv("data.csv")                                      # df -> dataframe, create a table from a csv file

# %%
df.head(10)                                 # first ten rows
# Out:
#                                                title  \
# 0      Climate action needs new frontline leadership
# 1        The dark history of the overthrow of Hawaii
# 2     How play can spark new ideas for your business
# 3  Why is China appointing judges to combat clima...
# 4     Cement's carbon problem — and 2 ways to fix it
# 5  The tragedy of air pollution — and an urgent d...
# 6                     The myth of Narcissus and Echo
# 7         You deserve the right to repair your stuff
# 8  What nature can teach us about sustainable bus...
# 9     The origins of blackface and Black stereotypes
#
#                        author            date   views  likes  \
# 0        Ozawa Bineshi Albert   December 2021  404000  12000
# 1               Sydney Iaukea   February 2022  214000   6400
# 2               Martin Reeves  September 2021  412000  12000
# 3           James K. Thornton    October 2021  427000  12000
# 4             Mahendra Singhi    October 2021    2400     72
# ...

# %%
df.tail(10)                                                     # last ten rows
# Out:
#                                                  title               author  \
# 5430                   My wish: Help me stop pandemics      Larry Brilliant
# 5431  Let's teach religion — all religion — in schools          Dan Dennett
# 5432                                 A life of purpose          Rick Warren
# 5433                                 Letting go of God        Julia Sweeney
# 5434            Behind the design of Seattle's library  Joshua Prince-Ramus
# 5435                   The best stats you've ever seen         Hans Rosling
# 5436                       Do schools kill creativity?     Sir Ken Robinson
# 5437                               Greening the ghetto        Majora Carter
# 5438                                  Simplicity sells          David Pogue
# 5439                       Averting the climate crisis              Al Gore
#
#                date     views    likes  \
# 5430  February 2006   1400000    42000
# 5431  February 2006   4099999   124000
# ...

# %%
df.info()                                               # data types and content of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5440 entries, 0 to 5439
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5440 non-null   object
#  1   author  5439 non-null   object
#  2   date    5440 non-null   object
#  3   views   5440 non-null   int64
#  4   likes   5440 non-null   int64
#  5   link    5440 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 255.1+ KB

# %%
df.describe()                                  #statistical measures (average, max, min)
# Out:
#               views         likes
# count  5.440000e+03  5.440000e+03
# mean   2.061576e+06  6.260762e+04
# std    3.567098e+06  1.076468e+05
# min    5.320000e+02  1.500000e+01
# 25%    6.707500e+05  2.000000e+04
# 50%    1.300000e+06  4.050000e+04
# 75%    2.100000e+06  6.500000e+04
# max    7.200000e+07  2.100000e+06

# %%
df.isna().sum()
# Out:
# title     0
# author    1
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
df.author.sort_values(na_position="first").head(15)
# Out:
# 3039                             NaN
# 3069                    B.E.A.T. NYC
# 736                       Beautyrest
# 14               Belle and Sebastian
# 933                     Butterscotch
# 1390                Climbing PoeTree
# 65                         Countdown
# 1569                      Crush Club
# 1692     Deutsche Philharmonie Merck
# 1239                   First Aid Kit
# 1452                Flor de Toloache
# 2250                            IN-Q
# 2154                              JR
# 80              Joan As Police Woman
# 27                               Kaz
# Name: author, dtype: object

# %%
df[df["author"] == "Bill Gates"]
# Out:
#                                                   title      author  \
# 403   The innovations we need to avoid a climate dis...  Bill Gates
# 789         How the pandemic will shape the near future  Bill Gates
# 952     How we must respond to the coronavirus pandemic  Bill Gates
# 3251                 The next outbreak? We're not ready  Bill Gates
# 3878                        Teachers need real feedback  Bill Gates
# 4560          How state budgets are breaking US schools  Bill Gates
# 4824                                Innovating to zero!  Bill Gates
# 5062                   Mosquitos, malaria and education  Bill Gates
#
#                date     views    likes  \
# 403      March 2021   1700000    53000
# 789       June 2020   4600000   138000
# 952      March 2020   8600000   259000
# 3251     March 2015  43000000  1300000
# 3878       May 2013   4500000   135000
# 4560     March 2011   2100000    63000
# 4824  February 2010   8100000   245000
# ...

# %%
#df = df.drop(index = 3039)

# %%
df.iloc[[3039]]
# Out:
#                    title author           date  views  likes  \
# 3039  Year In Ideas 2015    NaN  December 2015    532     15
#
#                                           link
# 3039  https://ted.com/talks/year_in_ideas_2015

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# title     0
# author    0
# date      0
# views     0
# likes     0
# link      0
# dtype: int64

# %%
month = []
year = []

for date in df["date"]:
    month.append(date.split(" ")[0])
    year.append(date.split(" ")[1])

df["month"] = month
df["year"] = year

df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link      month  year
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...   December  2021
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...   February  2022
# 2  https://ted.com/talks/martin_reeves_how_play_c...  September  2021
# ...

# %%
# df_temp = df["temperature"]                           # shows only one column in this case temperature

# %%
#pd.DataFrame(data = df_temp)

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5439 entries, 0 to 5439
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5439 non-null   object
#  1   author  5439 non-null   object
#  2   date    5439 non-null   object
#  3   views   5439 non-null   int64
#  4   likes   5439 non-null   int64
#  5   link    5439 non-null   object
#  6   month   5439 non-null   object
#  7   year    5439 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 382.4+ KB

# %%
df["year"] = df["year"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5439 entries, 0 to 5439
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   5439 non-null   object
#  1   author  5439 non-null   object
#  2   date    5439 non-null   object
#  3   views   5439 non-null   int64
#  4   likes   5439 non-null   int64
#  5   link    5439 non-null   object
#  6   month   5439 non-null   object
#  7   year    5439 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 382.4+ KB

# %%
df.groupby("month").size().sort_values(ascending = False)
# Out:
# month
# February     725
# November     682
# October      585
# March        580
# April        576
# June         493
# July         446
# September    349
# December     334
# May          322
# August       200
# January      147
# dtype: int64

# %%
df.groupby("year").size().sort_values(ascending = False)
# Out:
# year
# 2019    544
# 2020    501
# 2017    495
# 2018    473
# 2016    399
# 2021    390
# 2013    388
# 2015    376
# 2014    357
# 2012    302
# 2011    271
# 2010    267
# 2009    233
# 2007    113
# 2008     84
# 2005     65
# 2006     49
# 2003     34
# 2004     33
# 2002     26
# 2022     20
# 1998      6
# 2001      5
# 1970      2
# 1972      1
# 1994      1
# 1991      1
# 1990      1
# 1984      1
# 1983      1
# dtype: int64

# %%
df.groupby("year").size().sort_values(ascending = False).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df.groupby("year").size().sort_values(ascending = False).plot(kind="line")
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df.groupby("year").size().sort_values(ascending = False).plot(kind="area")
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df.groupby("year").size().plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='year'>

# %%
df.groupby("author").size().sort_values(ascending = False).head(10)
# Out:
# author
# Alex Gendler        45
# Iseult Gillespie    33
# Matt Walker         18
# Alex Rosenthal      15
# Elizabeth Cox       13
# Emma Bryce          12
# Daniel Finkel       11
# Juan Enriquez       11
# Dan Finkel           9
# Hans Rosling         9
# dtype: int64

# %%
df["author"].unique().size
# Out:
# 4443

# %%
df.groupby("author").size().sort_values(ascending = False).head(10).plot(kind = "bar")
# Out:
# <AxesSubplot: xlabel='author'>

# %%
df[df["author"] == "Alex Gendler"]
# Out:
#                                                   title        author  \
# 66    Blood, concrete, and dynamite: Building the Ho...  Alex Gendler
# 329                     The woman who stared at the sun  Alex Gendler
# 348     How one design flaw almost toppled a skyscraper  Alex Gendler
# 358   Demolition, disease, and death: Building the P...  Alex Gendler
# 367        How the world's tallest skyscraper was built  Alex Gendler
# 372      Why are airplanes slower than they used to be?  Alex Gendler
# 522   Building the world's largest (and most controv...  Alex Gendler
# 525              Can you solve the monster duel riddle?  Alex Gendler
# 548       Can you solve the Alice in Wonderland riddle?  Alex Gendler
# 757            The Egyptian myth of the death of Osiris  Alex Gendler
# 827                    Which voting system is the best?  Alex Gendler
# 864                            How do ventilators work?  Alex Gendler
# ...

# %%
df.groupby(['likes']).max().sort_values(by = "likes", ascending = False).head(10)
# Out:
#                                                      title            author  \
# likes
# 2100000                        Do schools kill creativity?  Sir Ken Robinson
# 1900000           Your body language may shape who you are         Amy Cuddy
# 1800000         Inside the mind of a master procrastinator         Tim Urban
# 1700000                         The power of vulnerability       Simon Sinek
# 1400000         How to speak so that people want to listen   Julian Treasure
# 1300000                 The next outbreak? We're not ready         Sam Berns
# 1200000  What makes a good life? Lessons from the longe...  Robert Waldinger
# 1100000                 Why people believe they can't draw        Mary Roach
# 1000000                          The orchestra in my mouth          Tom Thum
# 953000                                  How to spot a liar      Pamela Meyer
#
#                    date     views  \
# likes
# 2100000   February 2006  72000000
# ...

# %%
df.groupby(['views']).max().sort_values(by = "views", ascending = False).head(10)
# Out:
#                                                       title            author  \
# views
# 72000000                        Do schools kill creativity?  Sir Ken Robinson
# 64000000           Your body language may shape who you are         Amy Cuddy
# 60000000         Inside the mind of a master procrastinator         Tim Urban
# 57000000                   How great leaders inspire action       Simon Sinek
# 56000000                         The power of vulnerability       Brené Brown
# 49000000         How to speak so that people want to listen   Julian Treasure
# 43000000                 The next outbreak? We're not ready         Sam Berns
# 41000000  What makes a good life? Lessons from the longe...  Robert Waldinger
# 38000000  Looks aren't everything. Believe me, I'm a model.   Cameron Russell
# 37000000                 Why people believe they can't draw        Mary Roach
#
#                     date    likes  \
# views
# 72000000   February 2006  2100000
# ...

# %%
ratio = []

data = df.values

for i in range(len(data)):
    ratio.append(data[i][3]/data[i][4])

df["v&l_ratio"] = ratio

df.sort_values(by = "v&l_ratio", ascending = False).head(10)
# Out:
#                                                   title  \
# 955                A camera that can see around corners
# 905                      What's the point(e) of ballet?
# 837   How to see more and care less: The art of Geor...
# 26    Can you outsmart the fallacy that divided a na...
# 1016             The function and fashion of eyeglasses
# 3089             How computers translate human language
# 4389                            The right to understand
# 4362                           How to topple a dictator
# 5129                                         On glamour
# 1125                   Hacking bacteria to fight cancer
#
#                      author           date   views  likes  \
# 955           David Lindell  November 2019  364000  10000
# 905               Ming Luke     April 2020  364000  10000
# 837        Iseult Gillespie      June 2020  364000  10000
# 26            Elizabeth Cox  February 2022  363000  10000
# ...

# %%
tag = "education"

data = df.values

for i in range(len(data)):
    if (tag in data[i][0]):
        print(data[i][0], data[i][5])
# Out:
# Sex education should start with consent https://ted.com/talks/kaz_sex_education_should_start_with_consent
# 3 ways to lower the barriers to higher education https://ted.com/talks/adrian_k_haugabrook_3_ways_to_lower_the_barriers_to_higher_education
# What COVID-19 revealed about US schools — and 4 ways to rethink education https://ted.com/talks/nora_flanagan_what_covid_19_revealed_about_us_schools_and_4_ways_to_rethink_education
# Rethinking education and celebrating the Arabic language https://ted.com/talks/ahmad_m_hasnah_rethinking_education_and_celebrating_the_arabic_language
# A path to higher education and employment for refugees https://ted.com/talks/chrystina_russell_a_path_to_higher_education_and_employment_for_refugees
# The "opportunity gap" in US public education — and how to close it https://ted.com/talks/anindya_kundu_the_opportunity_gap_in_us_public_education_and_how_to_close_it
# ...

# %%
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
tag2 = "engineering"

data = df.values

for i in range(len(data)):
    if (tag2 in data[i][0]):
        print(data[i][0], data[i][5])
# Out:
# Mammoths resurrected, geoengineering and other thoughts from a futurist https://ted.com/talks/stewart_brand_and_chris_anderson_mammoths_resurrected_geoengineering_and_other_thoughts_from_a_futurist
# The case for engineering our food https://ted.com/talks/pamela_ronald_the_case_for_engineering_our_food
# To create for the ages, let's combine art and engineering https://ted.com/talks/bran_ferren_to_create_for_the_ages_let_s_combine_art_and_engineering
# Re-engineering mosquitos to fight disease https://ted.com/talks/hadyn_parry_re_engineering_mosquitos_to_fight_disease
# Could tissue engineering mean personalized medicine? https://ted.com/talks/nina_tandon_could_tissue_engineering_mean_personalized_medicine
# It's time to question bio-engineering https://ted.com/talks/paul_root_wolpe_it_s_time_to_question_bio_engineering
# Re-engineering the brain https://ted.com/talks/gero_miesenboeck_re_engineering_the_brain
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5439 entries, 0 to 5439
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      5439 non-null   object
#  1   author     5439 non-null   object
#  2   date       5439 non-null   object
#  3   views      5439 non-null   int64
#  4   likes      5439 non-null   int64
#  5   link       5439 non-null   object
#  6   month      5439 non-null   object
#  7   year       5439 non-null   int64
#  8   v&l_ratio  5439 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 424.9+ KB

# %%
top_authors = df.groupby(['author']).sum()["views"].sort_values(ascending = False).head(10)
top_authors
# Out:
# author
# Alex Gendler        187196000
# Sir Ken Robinson     95654000
# Bill Gates           77800000
# Simon Sinek          74800000
# Brené Brown          72000000
# Julian Treasure      64300000
# Amy Cuddy            64000000
# Tim Urban            60000000
# Iseult Gillespie     54998000
# Mia Nacamulli        44174000
# Name: views, dtype: int64

# %%
top_authors.sort_values(ascending = True).plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='author'>

# %%
df.to_csv("ted_talks_clean.csv")
